# %% [markdown]
# ## Lab 1: Data in Python
#
# The data for this activity can be downloaded here (under "Data Sets"): https://www.statlearning.com/resources-python

# %% [markdown]
# As a first step, create a folder in this location called "data" and drop the Credit.csv file in that location.
#
# If you open the ".gitignore" file, you'll notice that one of the entries is "data" so that your data files will not be shared on GitHub.

# %%
import pandas as pd
import numpy as np
Credit = pd.read_csv('data/Credit.csv')
Credit
# Out:
#       Income  Limit  Rating  Cards  Age  ...  Own Student Married Region Balance
# 0     14.891   3606     283      2   34  ...   No      No     Yes  South     333
# 1    106.025   6645     483      3   82  ...  Yes     Yes     Yes   West     903
# 2    104.593   7075     514      4   71  ...   No      No      No   West     580
# 3    148.924   9504     681      3   36  ...  Yes      No      No   West     964
# 4     55.882   4897     357      2   68  ...   No      No     Yes  South     331
# ..       ...    ...     ...    ...  ...  ...  ...     ...     ...    ...     ...
# 395   12.096   4100     307      3   32  ...   No      No     Yes  South     560
# 396   13.364   3838     296      5   65  ...   No      No      No   East     480
# 397   57.872   4171     321      5   67  ...  Yes      No     Yes  South     138
# 398   37.728   2525     192      1   44  ...   No      No     Yes  South       0
# 399   18.701   5524     415      5   64  ...  Yes      No      No   West     966
#
# [400 rows x 11 columns]

# %% [markdown]
# ### What are the feature names?

# %%
Credit.columns.tolist()
# Out:
# ['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Own', 'Student', 'Married', 'Region', 'Balance']

# %% [markdown]
# ### What are the data types of the feature values (i.e., numeric, categorical)

# %%
Credit.dtypes
# Out:
# Income       float64
# Limit          int64
# Rating         int64
# Cards          int64
# Age            int64
# Education      int64
# Own           object
# Student       object
# Married       object
# Region        object
# Balance        int64
# dtype: object

# %% [markdown]
# ### Find the mean, median, and mode of the feature "Age."

# %%
# mean
Credit['Age'].mean()
# Out:
# np.float64(55.6675)

# %%
# median
Credit['Age'].median()
# Out:
# np.float64(56.0)

# %%
# mode
Credit['Age'].mode()
# Out:
# 0    44
# 1    66
# Name: Age, dtype: int64

# %% [markdown]
# ### Create a subset of Credit that only contains the columns Age, Region, and Income. Call it "Subset."

# %%
Subset = Credit[['Age', 'Region', 'Income']]
Subset
# Out:
#      Age Region   Income
# 0     34  South   14.891
# 1     82   West  106.025
# 2     71   West  104.593
# 3     36   West  148.924
# 4     68  South   55.882
# ..   ...    ...      ...
# 395   32  South   12.096
# 396   65   East   13.364
# 397   67  South   57.872
# 398   44  South   37.728
# 399   64   West   18.701
#
# [400 rows x 3 columns]

# %% [markdown]
# ### From this subset, create two partitions:
# - One that contains records for Ages below 50, and one that contains Ages 50+
# - Call them "Younger" and "Older"

# %%
Younger = Subset[Subset['Age'] < 50]
Younger
# Out:
#      Age Region   Income
# 0     34  South   14.891
# 3     36   West  148.924
# 6     37   East   20.996
# 9     41   East   71.061
# 10    30  South   63.095
# ..   ...    ...      ...
# 391   43  South   73.327
# 392   24   West   25.974
# 394   40  South   49.794
# 395   32  South   12.096
# 398   44  South   37.728
#
# [161 rows x 3 columns]

# %%
Older = Subset[Subset['Age'] >= 50]
Older
# Out:
#      Age Region   Income
# 1     82   West  106.025
# 2     71   West  104.593
# 4     68  South   55.882
# 5     77  South   80.180
# 7     87   West   71.408
# ..   ...    ...      ...
# 390   81   West  135.118
# 393   65   East   17.316
# 396   65   East   13.364
# 397   67  South   57.872
# 399   64   West   18.701
#
# [239 rows x 3 columns]

# %% [markdown]
# ### Use these partitions to compare the mean and median Income for each age group (less than 50 vs. 50+)

# %%
# mean of younger
Younger['Income'].mean()
# Out:
# np.float64(41.65203726708074)

# %%
# mean of older
Older['Income'].mean()
# Out:
# np.float64(47.6216569037657)

# %%
# median of younger
Younger['Income'].median()
# Out:
# np.float64(31.861)

# %%
# median of older
Older['Income'].median()
# Out:
# np.float64(33.694)

# %% [markdown]
# ### What does the difference between mean and median suggest about the distribution of income?

# %% [markdown]
# For both age groups, the mean income is higher than the median income. This suggests that income is right-skewed: a relatively small number of high-income observations pull each mean upward. The older group also has a higher typical income than the younger group, based on both measures.

# %% [markdown]
# ### What are the possible values for Region?

# %%
Credit['Region'].unique()
# Out:
# array(['South', 'West', 'East'], dtype=object)

# %% [markdown]
# ### Use the value_counts method to build a frequency table for the possible values of Region.

# %%
Credit['Region'].value_counts()
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %% [markdown]
# ### Compare the average income for students vs. non-students.

# %%
StudentIncome = Credit[Credit['Student'] == 'Yes']['Income']

# %%
NonStudentIncome = Credit[Credit['Student'] == 'No']['Income']

# %%
# Average income for students
StudentIncome.mean()
# Out:
# np.float64(47.29205)

# %%
# Average income for non-students
NonStudentIncome.mean()
# Out:
# np.float64(44.988533333333336)

# %% [markdown]
# Often, banks will use a variable called _utilization_ to assess credit risk.
# Utilization is the ratio of balance to limit (i.e., what % of the credit limit is being used?)
# ### Add a feature to the Credit dataset to measure utilization

# %%
Credit['Utilization'] = Credit['Balance'] / Credit['Limit']

# %%
Credit[['Balance', 'Limit', 'Utilization']].head()
# Out:
#    Balance  Limit  Utilization
# 0      333   3606     0.092346
# 1      903   6645     0.135892
# 2      580   7075     0.081979
# 3      964   9504     0.101431
# 4      331   4897     0.067592

# %% [markdown]
# ### What is the maximum utilization value in this set?

# %%
Credit['Utilization'].max()
# Out:
# np.float64(0.27693008426326576)
